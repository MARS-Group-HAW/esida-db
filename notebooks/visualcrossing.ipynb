# %%
import pandas as pd

# prevent false warning
# https://stackoverflow.com/questions/20625582/how-to-deal-with-settingwithcopywarning-in-pandas
pd.options.mode.chained_assignment = None  # default='warn'

import matplotlib.pyplot as plt
import matplotlib.ticker as mtick
import numpy as np

# %%
#Downloading weather data using Python as a CSV using the Visual Crossing Weather API
#See https://www.visualcrossing.com/resources/blog/how-to-load-historical-weather-data-using-python-without-scraping/ for more information.
import csv
import codecs
import urllib.request
import urllib.error
import sys

# This is the core of our weather query URL
BaseURL = 'https://weather.visualcrossing.com/VisualCrossingWebServices/rest/services/timeline/'

ApiKey='PRYLRKJQZXXEK4YCXLLNEW525'
#UnitGroup sets the units of the output - us or metric
UnitGroup='metric'

#Location for the weather data
Location='kigoma,tz'

#Optional start and end dates
#If nothing is specified, the forecast is retrieved. 
#If start date only is specified, a single historical or forecast day will be retrieved
#If both start and and end date are specified, a date range will be retrieved
StartDate = '2018-01-01'
EndDate='2018-01-14'

#JSON or CSV 
#JSON format supports daily, hourly, current conditions, weather alerts and events in a single JSON package
#CSV format requires an 'include' parameter below to indicate which table section is required
ContentType="csv"

#include sections
#values include days,hours,current,alerts
Include="days"


print('')
print(' - Requesting weather : ')

#basic query including location
ApiQuery=BaseURL + Location

#append the start and end date if present
if (len(StartDate)):
    ApiQuery+="/"+StartDate
    if (len(EndDate)):
        ApiQuery+="/"+EndDate

#Url is completed. Now add query parameters (could be passed as GET or POST)
ApiQuery+="?"

#append each parameter as necessary
if (len(UnitGroup)):
    ApiQuery+="&unitGroup="+UnitGroup

if (len(ContentType)):
    ApiQuery+="&contentType="+ContentType

if (len(Include)):
    ApiQuery+="&include="+Include

ApiQuery+="&key="+ApiKey



print(' - Running query URL: ', ApiQuery)
print()

try: 
    CSVBytes = urllib.request.urlopen(ApiQuery)
except urllib.error.HTTPError  as e:
    ErrorInfo= e.read().decode() 
    print('Error code: ', e.code, ErrorInfo)
    sys.exit()
except  urllib.error.URLError as e:
    ErrorInfo= e.read().decode() 
    print('Error code: ', e.code,ErrorInfo)
    sys.exit()


# Parse the results as CSV
CSVText = csv.reader(codecs.iterdecode(CSVBytes, 'utf-8'))

RowIndex = 0

# The first row contain the headers and the additional rows each contain the weather metrics for a single day
# To simply our code, we use the knowledge that column 0 contains the location and column 1 contains the date.  The data starts at column 4
for Row in CSVText:
    if RowIndex == 0:
        FirstRow = Row
    else:
        print('Weather in ', Row[0], ' on ', Row[1])

        ColIndex = 0
        for Col in Row:
            if ColIndex >= 4:
                print('   ', FirstRow[ColIndex], ' = ', Row[ColIndex])
            ColIndex += 1
    RowIndex += 1

# If there are no CSV rows then something fundamental went wrong
if RowIndex == 0:
    print('Sorry, but it appears that there was an error connecting to the weather server.')
    print('Please check your network connection and try again..')

# If there is only one CSV  row then we likely got an error from the server
if RowIndex == 1:
    print('Sorry, but it appears that there was an error retrieving the weather data.')
    print('Error: ', FirstRow)

print()
# Out:
#  - Requesting weather :
#  - Running query URL:  https://weather.visualcrossing.com/VisualCrossingWebServices/rest/services/timeline/kigoma,tz/2018-01-01/2018-01-14?&unitGroup=metric&contentType=csv&include=days&key=PRYLRKJQZXXEK4YCXLLNEW525
#
# Weather in  Kigoma, Tanzania  on  2018-01-01
#     temp  =  22.9
#     feelslikemax  =  29.3
#     feelslikemin  =  20.5
#     feelslike  =  23.1
#     dew  =  20.5
#     humidity  =  87
#     precip  =  9.3
#     precipprob  =  100
#     precipcover  =  79.17
#     preciptype  =  rain
#     snow  =
#     snowdepth  =
#     windgust  =
#     windspeed  =  25.9
#     winddir  =  211.5
#     sealevelpressure  =
#     cloudcover  =  69.2
#     visibility  =  16.2
#     solarradiation  =  170
#     solarenergy  =  14.7
#     uvindex  =  6
#     severerisk  =
#     sunrise  =  2018-01-01T06:52:57
#     sunset  =  2018-01-01T19:16:41
#     moonphase  =  0.5
#     conditions  =  Rain, Partially cloudy
#     description  =  Partly cloudy throughout the day with a chance of rain throughout the day.
#     icon  =  rain
#     stations  =  63801099999,HTKA,remote
# Weather in  Kigoma, Tanzania  on  2018-01-02
#     temp  =  23.6
#     feelslikemax  =  29.5
#     feelslikemin  =  20
#     feelslike  =  24.1
#     dew  =  20.4
#     humidity  =  82.9
#     precip  =  0
#     precipprob  =  0
#     precipcover  =  0
#     preciptype  =
#     snow  =
#     snowdepth  =
#     windgust  =
#     windspeed  =  27.7
#     winddir  =  80.9
#     sealevelpressure  =
#     cloudcover  =  70.6
#     visibility  =  13.6
#     solarradiation  =  289.7
#     solarenergy  =  25.1
#     uvindex  =  9
#     severerisk  =
#     sunrise  =  2018-01-02T06:53:27
#     sunset  =  2018-01-02T19:17:07
#     moonphase  =  0.5
#     conditions  =  Partially cloudy
#     description  =  Partly cloudy throughout the day.
#     icon  =  partly-cloudy-day
#     stations  =  63801099999,HTKA,remote
# Weather in  Kigoma, Tanzania  on  2018-01-03
#     temp  =  23.8
#     feelslikemax  =  30.1
#     feelslikemin  =  19.9
#     feelslike  =  24.2
#     dew  =  19.9
#     humidity  =  80.3
#     precip  =  4.6
#     precipprob  =  100
#     precipcover  =  79.17
#     preciptype  =  rain
#     snow  =
#     snowdepth  =
#     windgust  =
#     windspeed  =  20.5
#     winddir  =  152.6
#     sealevelpressure  =
#     cloudcover  =  57.7
#     visibility  =  16.7
#     solarradiation  =  238.2
#     solarenergy  =  20.7
#     uvindex  =  9
#     severerisk  =
#     sunrise  =  2018-01-03T06:53:57
#     sunset  =  2018-01-03T19:17:32
#     moonphase  =  0.52
#     conditions  =  Rain, Partially cloudy
#     description  =  Partly cloudy throughout the day with a chance of rain throughout the day.
#     icon  =  rain
#     stations  =  63801099999,HTKA,remote
# Weather in  Kigoma, Tanzania  on  2018-01-04
#     temp  =  22.3
#     feelslikemax  =  25
#     feelslikemin  =  20
#     feelslike  =  22.3
#     dew  =  20.4
#     humidity  =  89.2
#     precip  =  7.1
#     precipprob  =  100
#     precipcover  =  87.5
#     preciptype  =  rain
#     snow  =
#     snowdepth  =
#     windgust  =
#     windspeed  =  18.4
#     winddir  =  121
#     sealevelpressure  =
#     cloudcover  =  75.2
#     visibility  =  14.5
#     solarradiation  =  248.6
#     solarenergy  =  21.4
#     uvindex  =  9
#     severerisk  =
#     sunrise  =  2018-01-04T06:54:27
#     sunset  =  2018-01-04T19:17:57
#     moonphase  =  0.54
#     conditions  =  Rain, Partially cloudy
#     description  =  Partly cloudy throughout the day with a chance of rain throughout the day.
#     icon  =  rain
#     stations  =  63801099999,HTKA,remote
# Weather in  Kigoma, Tanzania  on  2018-01-05
#     temp  =  22.6
#     feelslikemax  =  30.2
#     feelslikemin  =  20
#     feelslike  =  22.8
#     dew  =  20.1
#     humidity  =  86.8
#     precip  =  4.3
#     precipprob  =  100
#     precipcover  =  100
#     preciptype  =  rain
#     snow  =
#     snowdepth  =
#     windgust  =
#     windspeed  =  18.4
#     winddir  =  162.9
#     sealevelpressure  =
#     cloudcover  =  84.1
#     visibility  =  16.3
#     solarradiation  =  124.4
#     solarenergy  =  11
#     uvindex  =  5
#     severerisk  =
#     sunrise  =  2018-01-05T06:54:57
#     sunset  =  2018-01-05T19:18:21
#     moonphase  =  0.58
#     conditions  =  Rain, Partially cloudy
#     description  =  Partly cloudy throughout the day with a chance of rain throughout the day.
#     icon  =  rain
#     stations  =  63801099999,HTKA,remote
# Weather in  Kigoma, Tanzania  on  2018-01-06
#     temp  =  21.8
#     feelslikemax  =  23.6
#     feelslikemin  =  19.4
#     feelslike  =  21.8
#     dew  =  19.2
#     humidity  =  85.7
#     precip  =  13.9
#     precipprob  =  100
#     precipcover  =  100
#     preciptype  =  rain
#     snow  =
#     snowdepth  =
#     windgust  =
#     windspeed  =  17.3
#     winddir  =  269.7
#     sealevelpressure  =
#     cloudcover  =  80.6
#     visibility  =  30
#     solarradiation  =  166.3
#     solarenergy  =  14.4
#     uvindex  =  6
#     severerisk  =
#     sunrise  =  2018-01-06T06:55:26
#     sunset  =  2018-01-06T19:18:44
#     moonphase  =  0.63
#     conditions  =  Rain, Partially cloudy
#     description  =  Partly cloudy throughout the day with a chance of rain throughout the day.
#     icon  =  rain
#     stations  =  63801099999,remote
# Weather in  Kigoma, Tanzania  on  2018-01-07
#     temp  =  22.7
#     feelslikemax  =  26.1
#     feelslikemin  =  19.9
#     feelslike  =  22.7
#     dew  =  18
#     humidity  =  76.3
#     precip  =  2.7
#     precipprob  =  100
#     precipcover  =  66.67
#     preciptype  =  rain
#     snow  =
#     snowdepth  =
#     windgust  =
#     windspeed  =  15.8
#     winddir  =  286.3
#     sealevelpressure  =
#     cloudcover  =  73.7
#     visibility  =  30
#     solarradiation  =  260.8
#     solarenergy  =  22.5
#     uvindex  =  9
#     severerisk  =
#     sunrise  =  2018-01-07T06:55:55
#     sunset  =  2018-01-07T19:19:07
#     moonphase  =  0.68
#     conditions  =  Rain, Partially cloudy
#     description  =  Partly cloudy throughout the day with a chance of rain throughout the day.
#     icon  =  rain
#     stations  =  63801099999,remote
# Weather in  Kigoma, Tanzania  on  2018-01-08
#     temp  =  22.9
#     feelslikemax  =  29
#     feelslikemin  =  20.4
#     feelslike  =  23
#     dew  =  19.1
#     humidity  =  80.6
#     precip  =  5.1
#     precipprob  =  100
#     precipcover  =  100
#     preciptype  =  rain
#     snow  =
#     snowdepth  =
#     windgust  =
#     windspeed  =  18.4
#     winddir  =  255.5
#     sealevelpressure  =
#     cloudcover  =  70.7
#     visibility  =  30
#     solarradiation  =  237
#     solarenergy  =  20.4
#     uvindex  =  9
#     severerisk  =
#     sunrise  =  2018-01-08T06:56:24
#     sunset  =  2018-01-08T19:19:29
#     moonphase  =  0.73
#     conditions  =  Rain, Partially cloudy
#     description  =  Partly cloudy throughout the day with a chance of rain throughout the day.
#     icon  =  rain
#     stations  =  63801099999,remote
# Weather in  Kigoma, Tanzania  on  2018-01-09
#     temp  =  22.5
#     feelslikemax  =  29.9
#     feelslikemin  =  19.9
#     feelslike  =  22.6
#     dew  =  18.1
#     humidity  =  77.1
#     precip  =  8.6
#     precipprob  =  100
#     precipcover  =  50
#     preciptype  =  rain
#     snow  =
#     snowdepth  =
#     windgust  =
#     windspeed  =  16.6
#     winddir  =  276.1
#     sealevelpressure  =
#     cloudcover  =  85.1
#     visibility  =  30
#     solarradiation  =  163.4
#     solarenergy  =  14.1
#     uvindex  =  5
#     severerisk  =
#     sunrise  =  2018-01-09T06:56:53
#     sunset  =  2018-01-09T19:19:51
#     moonphase  =  0.78
#     conditions  =  Rain, Partially cloudy
#     description  =  Partly cloudy throughout the day with rain clearing later.
#     icon  =  rain
#     stations  =  63801099999,remote
# Weather in  Kigoma, Tanzania  on  2018-01-10
#     temp  =  23.7
#     feelslikemax  =  31.2
#     feelslikemin  =  20.1
#     feelslike  =  23.8
#     dew  =  18.4
#     humidity  =  73.1
#     precip  =  0.4
#     precipprob  =  100
#     precipcover  =  16.67
#     preciptype  =  rain
#     snow  =
#     snowdepth  =
#     windgust  =
#     windspeed  =  18.4
#     winddir  =  247
#     sealevelpressure  =
#     cloudcover  =  75.2
#     visibility  =  30
#     solarradiation  =  269
#     solarenergy  =  23.4
#     uvindex  =  9
#     severerisk  =
#     sunrise  =  2018-01-10T06:57:21
#     sunset  =  2018-01-10T19:20:12
#     moonphase  =  0.83
#     conditions  =  Rain, Partially cloudy
#     description  =  Partly cloudy throughout the day with rain clearing later.
#     icon  =  rain
#     stations  =  63801099999,remote
# Weather in  Kigoma, Tanzania  on  2018-01-11
#     temp  =  23.3
#     feelslikemax  =  28.5
#     feelslikemin  =  20.2
#     feelslike  =  23.3
#     dew  =  18.7
#     humidity  =  76.4
#     precip  =  1.4
#     precipprob  =  100
#     precipcover  =  41.67
#     preciptype  =  rain
#     snow  =
#     snowdepth  =
#     windgust  =
#     windspeed  =  18.4
#     winddir  =  290.3
#     sealevelpressure  =
#     cloudcover  =  80.5
#     visibility  =  27.1
#     solarradiation  =  210.1
#     solarenergy  =  18
#     uvindex  =  8
#     severerisk  =
#     sunrise  =  2018-01-11T06:57:49
#     sunset  =  2018-01-11T19:20:32
#     moonphase  =  0.88
#     conditions  =  Rain, Partially cloudy
#     description  =  Partly cloudy throughout the day with rain in the morning and afternoon.
#     icon  =  rain
#     stations  =  63801099999,remote
# Weather in  Kigoma, Tanzania  on  2018-01-12
#     temp  =  22.7
#     feelslikemax  =  24.6
#     feelslikemin  =  21
#     feelslike  =  22.7
#     dew  =  19.5
#     humidity  =  82.6
#     precip  =  6.1
#     precipprob  =  100
#     precipcover  =  100
#     preciptype  =  rain
#     snow  =
#     snowdepth  =
#     windgust  =
#     windspeed  =  18.4
#     winddir  =  225.1
#     sealevelpressure  =
#     cloudcover  =  90.4
#     visibility  =  25
#     solarradiation  =  84
#     solarenergy  =  7.5
#     uvindex  =  3
#     severerisk  =
#     sunrise  =  2018-01-12T06:58:16
#     sunset  =  2018-01-12T19:20:51
#     moonphase  =  0.92
#     conditions  =  Rain, Overcast
#     description  =  Cloudy skies throughout the day with a chance of rain throughout the day.
#     icon  =  rain
#     stations  =  63801099999,HTKA,remote
# Weather in  Kigoma, Tanzania  on  2018-01-13
#     temp  =  22.2
#     feelslikemax  =  25.8
#     feelslikemin  =  20.2
#     feelslike  =  22.2
#     dew  =  19
#     humidity  =  82.9
#     precip  =  13
#     precipprob  =  100
#     precipcover  =  70.83
#     preciptype  =  rain
#     snow  =
#     snowdepth  =
#     windgust  =
#     windspeed  =  12.2
#     winddir  =  212
#     sealevelpressure  =
#     cloudcover  =  90.3
#     visibility  =  28.3
#     solarradiation  =  159.1
#     solarenergy  =  13.6
#     uvindex  =  7
#     severerisk  =
#     sunrise  =  2018-01-13T06:58:43
#     sunset  =  2018-01-13T19:21:09
#     moonphase  =  0.95
#     conditions  =  Rain, Overcast
#     description  =  Cloudy skies throughout the day with a chance of rain throughout the day.
#     icon  =  rain
#     stations  =  63801099999,HTKA,remote
# Weather in  Kigoma, Tanzania  on  2018-01-14
#     temp  =  23
#     feelslikemax  =  26.7
#     feelslikemin  =  20.8
#     feelslike  =  23
#     dew  =  18.8
#     humidity  =  78
#     precip  =  0.5
#     precipprob  =  100
#     precipcover  =  20.83
#     preciptype  =  rain
#     snow  =
#     snowdepth  =
#     windgust  =
#     windspeed  =  18.4
#     winddir  =  260.7
#     sealevelpressure  =
#     cloudcover  =  79
#     visibility  =  30
#     solarradiation  =  215.8
#     solarenergy  =  18.5
#     uvindex  =  8
#     severerisk  =
#     sunrise  =  2018-01-14T06:59:09
#     sunset  =  2018-01-14T19:21:27
#     moonphase  =  0.98
#     conditions  =  Rain, Partially cloudy
#     description  =  Partly cloudy throughout the day with rain.
#     icon  =  rain
#     stations  =  63801099999,remote

# %%
df = pd.DataFrame(CSVText)

# %%
with open('employee_file2.csv', mode='w') as csv_file:
    first = False
    fieldnames = None

    for Row in CSVText:
        print(Row)
        fieldnames = Row
        break
        
    print(fieldnames)
        
    writer = csv.DictWriter(csv_file, fieldnames=fieldnames)
    writer.writeheader()
    
    for Row in CSVText:
        
        if not first:
            first = True
            continue
        
        writer.writerow(Row)
# Out:
# None
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [12], in <cell line: 1>()
#      10 print(fieldnames)
#      12 writer = csv.DictWriter(csv_file, fieldnames=fieldnames)
# ---> 13 writer.writeheader()
#      15 for Row in CSVText:
#      17     if not first:
#
# File /opt/homebrew/Cellar/python@3.9/3.9.12/Frameworks/Python.framework/Versions/3.9/lib/python3.9/csv.py:142, in DictWriter.writeheader(self)
#     141 def writeheader(self):
# --> 142     header = dict(zip(self.fieldnames, self.fieldnames))
#     143     return self.writerow(header)
#
# TypeError: 'NoneType' object is not iterable

# %%
for row in CSVText:
    print(x)
    print(row)

# %%
CSVBytes.read().content
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [20], in <cell line: 1>()
# ----> 1 CSVBytes.read().content
#
# AttributeError: 'bytes' object has no attribute 'content'
