# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.ticker as mtick

import geopandas


import numpy as np

import shapely.wkt

import osmnx as ox

ox.settings.log_console=True

# %%
# TZ convex hull
tza = shapely.wkt.loads('POLYGON((36.51663051180202 -11.76400833641038,34.96148292189685 -11.57459896625327,34.96058197176314 -11.57433910112481,31.17774355463043 -8.599754824872136,29.72620481349243 -6.245866261163819,29.72511552786495 -6.24409782337949,29.72380939573032 -6.241814222429691,29.7230927952378 -6.239093880200518,29.72281445693241 -6.236669876630748,29.59019453157737 -4.9111553760294,29.60174686518157 -4.748289022027135,29.65513992021926 -4.475508561052573,29.655536158368 -4.473626633198812,29.65999383707959 -4.45272733051314,30.5010559612266 -1.069557216108248,30.50168993671256 -1.067188584728907,30.76681900204326 -0.985787540066914,34.09345663886533 -1.028860821851255,37.47673403145131 -2.934585354550944,37.50147252618095 -2.948744403373551,37.5079277503655 -2.952578919419102,37.52476915414628 -2.962740677865566,37.54887874123757 -2.97746242521771,37.54953281796728 -2.977899185833122,37.55215701305151 -2.979651507804265,37.56101067189169 -2.985563594112739,37.60151493196877 -3.01261057250798,37.62360183359599 -3.027570966651026,37.62433622001061 -3.028068400632912,37.67145113561096 -3.06100829882439,39.86714817135311 -4.889450609313316,39.86998985049286 -4.892130746409637,39.87181271402675 -4.896867504414818,39.87462105754846 -4.90491261676847,39.87481540740413 -4.905660773235087,39.87498060504927 -4.906690703648619,40.44564084072362 -10.34828319153082,40.44557937828669 -10.35134869946121,40.41444609996741 -10.4985572059218,40.41376857934758 -10.50129182229417,40.41217316466955 -10.50448579103445,40.36164348871228 -10.56282399929405,39.99720481916869 -10.81590079143496,39.24962416337877 -11.17425332941982,39.24574931945642 -11.17595282265233,38.48849455259909 -11.4184123077983,38.48539226155694 -11.41938025691861,37.41436061608537 -11.68247473285284,37.39913517267601 -11.68551296968752,37.38961960603095 -11.68733336894736,37.38422813792191 -11.68823987578439,36.51663051180202 -11.76400833641038))')

# %%
gdf_osm = ox.geometries_from_polygon(
    tza,
    {
        'railway': "rail"
    }
)

# %%
gdf_osm.plot()
# Out:
# <AxesSubplot: >

# %%
gdfflat = gdf_osm.reset_index(drop=True)

# %%
gdfflat
# Out:
#      railway source                                           geometry
# 0       rail    GPS  LINESTRING (36.35757 -8.17416, 36.36864 -8.168...  \
# 1       rail    GPS  LINESTRING (36.35703 -8.17445, 36.35757 -8.17416)
# 2       rail    GPS  LINESTRING (36.30451 -8.20118, 36.30541 -8.201...
# 3       rail    NaN  LINESTRING (36.56860 -8.08485, 36.57133 -8.084...
# 4       rail    NaN  LINESTRING (36.66480 -8.07799, 36.66600 -8.07769)
# ...      ...    ...                                                ...
# 2199    rail    NaN  LINESTRING (29.73164 -4.91191, 29.73195 -4.912...
# 2200    rail    NaN  LINESTRING (29.73246 -4.91322, 29.73269 -4.913...
# 2201    rail    NaN  LINESTRING (29.73195 -4.91233, 29.73144 -4.91146)
# 2202    rail    NaN  LINESTRING (30.00056 -4.99212, 30.00022 -4.992...
# 2203    rail    NaN  LINESTRING (29.99577 -4.99149, 29.99627 -4.991...
#
#                                                   nodes electrified gauge
# 0     [6166522386, 918742704, 918743746, 918743525, ...          no  1067  \
# 1                              [6166522387, 6166522386]          no  1067
# 2     [918743055, 2198518763, 2198518761, 918742842,...          no  1067
# 3     [6166522367, 6049323001, 2145964516, 711305713...          no  1067
# 4                               [1745548814, 918743554]          no  1067
# ...                                                 ...         ...   ...
# 2199  [9240035816, 9240068317, 9240068318, 924006831...         NaN   NaN
# 2200               [9240068318, 9240068321, 9240068322]         NaN   NaN
# 2201                           [9240068317, 9240068323]         NaN   NaN
# 2202  [9240068331, 9240068332, 5708529115, 924006833...         NaN   NaN
# 2203  [9240068335, 9240068336, 9240068340, 924006833...         NaN   NaN
#
#      passenger_lines usage bridge layer  ... wikipedia tracks
# 0                  1  main    NaN   NaN  ...       NaN    NaN  \
# 1                  1  main    yes     1  ...       NaN    NaN
# 2                  1  main    NaN   NaN  ...       NaN    NaN
# 3                  1  main    NaN   NaN  ...       NaN    NaN
# 4                  1  main    yes     1  ...       NaN    NaN
# ...              ...   ...    ...   ...  ...       ...    ...
# 2199             NaN   NaN    NaN   NaN  ...       NaN    NaN
# 2200             NaN   NaN    NaN   NaN  ...       NaN    NaN
# 2201             NaN   NaN    NaN   NaN  ...       NaN    NaN
# 2202             NaN   NaN    NaN   NaN  ...       NaN    NaN
# 2203             NaN   NaN    NaN   NaN  ...       NaN    NaN
#
#      public_transport:version level network attribution date _LONGUEUR_ route
# 0                         NaN   NaN     NaN         NaN  NaN        NaN   NaN  \
# 1                         NaN   NaN     NaN         NaN  NaN        NaN   NaN
# 2                         NaN   NaN     NaN         NaN  NaN        NaN   NaN
# 3                         NaN   NaN     NaN         NaN  NaN        NaN   NaN
# 4                         NaN   NaN     NaN         NaN  NaN        NaN   NaN
# ...                       ...   ...     ...         ...  ...        ...   ...
# 2199                      NaN   NaN     NaN         NaN  NaN        NaN   NaN
# 2200                      NaN   NaN     NaN         NaN  NaN        NaN   NaN
# 2201                      NaN   NaN     NaN         NaN  NaN        NaN   NaN
# 2202                      NaN   NaN     NaN         NaN  NaN        NaN   NaN
# 2203                      NaN   NaN     NaN         NaN  NaN        NaN   NaN
#
#      type
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
# ...   ...
# 2199  NaN
# 2200  NaN
# 2201  NaN
# 2202  NaN
# 2203  NaN
#
# [2204 rows x 44 columns]

# %%
gdf_osm2 = ox.graph_from_polygon(
    tza,
    custom_filter='["railway"~"rail"]'
)

# %%
gdf_nodes, gdf_edges = ox.graph_to_gdfs(gdf_osm2)
gdf_nodes = ox.io._stringify_nonnumeric_cols(gdf_nodes)
gdf_edges = ox.io._stringify_nonnumeric_cols(gdf_edges)

# %%
gdf_edges.plot()
# Out:
# <AxesSubplot: >
