# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.ticker as mtick

import numpy as np

import geopandas

# %%
gdf = geopandas.read_file('../input/data.local/hdx_hfr/suhsharan_health_facilities/sub-saharan_health_facilities.shp')

# %%
gdf = gdf[gdf['Country'] == 'Tanzania']

# %%
gdf['Facility t'].value_counts(dropna=False).rename_axis('unique_values').reset_index(name='counts')
# Out:
#                   unique_values  counts
# 0                    Dispensary    5406
# 1                 Health Centre     675
# 2                      Hospital      87
# 3             District Hospital      63
# 4  Designated District Hospital      36
# 5    Regional Referral Hospital      26
# 6             Referral Hospital      10
# 7             National Hospital       1

# %%
gdf = gdf.reset_index(drop=True)

# %%
gdf['id'] 0
# Out:
#         Country  Admin1                          Facility n     Facility t  \
# 85798  Tanzania  Arusha  Africa Amini Momella Health Centre  Health Centre
# 85799  Tanzania  Arusha                    Agape Dispensary     Dispensary
# 85800  Tanzania  Arusha                       AICC Hospital       Hospital
# 85801  Tanzania  Arusha                Alailelai Dispensary     Dispensary
# 85802  Tanzania  Arusha                  Alkaria Dispensary     Dispensary
# ...         ...     ...                                 ...            ...
# 92097  Tanzania   Tanga                 Vyadigwa Dispensary     Dispensary
# 92098  Tanzania   Tanga                    Vyeru Dispensary     Dispensary
# 92099  Tanzania   Tanga                     Zege Dispensary     Dispensary
# 92100  Tanzania   Tanga                   Zeneti Dispensary     Dispensary
# 92101  Tanzania   Tanga                    Zirai Dispensary     Dispensary
#
#              Ownership     Lat     Long    LL source  \
# ...
