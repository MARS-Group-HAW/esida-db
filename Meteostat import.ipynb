# %%
# !pip install meteostat
# Out:
# DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# Collecting meteostat
#   Downloading meteostat-1.6.1-py3-none-any.whl (30 kB)
# Requirement already satisfied: numpy in /opt/homebrew/lib/python3.9/site-packages (from meteostat) (1.22.3)
# Requirement already satisfied: pytz in /opt/homebrew/lib/python3.9/site-packages (from meteostat) (2021.3)
# Requirement already satisfied: pandas>=1.1 in /opt/homebrew/lib/python3.9/site-packages (from meteostat) (1.4.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /opt/homebrew/lib/python3.9/site-packages (from pandas>=1.1->meteostat) (2.8.2)
# Requirement already satisfied: six>=1.5 in /opt/homebrew/lib/python3.9/site-packages (from python-dateutil>=2.8.1->pandas>=1.1->meteostat) (1.16.0)
# Installing collected packages: meteostat
#   DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# Successfully installed meteostat-1.6.1
# WARNING: You are using pip version 22.0.3; however, version 22.0.4 is available.
# You should consider upgrading via the '/opt/homebrew/opt/python@3.9/bin/python3.9 -m pip install --upgrade pip' command.

# %%
from meteostat import Stations

# %%
stations = Stations()
stations = stations.region('TZ')

print('Stations in Tanzania:', stations.count())
# Out:
# Stations in Tanzania: 27

# %%
stations_df = stations.fetch()

# %%
stations_df
# Out:
#                                       name country region    wmo  icao  \
# id
# 63729                               Bukoba      TZ     KA  63729  HTBU
# 63733                               Musoma      TZ     MR  63733  HTMU
# 63756                               Mwanza      TZ     MW  63756  HTMW
# 63789                               Arusha      TZ     AR  63789  HTAR
# 63790                                Moshi      TZ     KJ  63790  HTMS
# 63791                  Kilimanjaro Airport      TZ     AR  63791  HTKJ
# 63801                               Kigoma      TZ     KI  63801  HTKA
# 63816                                 Same      TZ     KJ  63816  HTSE
# 63818                                Mombo      TZ     TN  63818  HTMO
# 63832                       Tabora Airport      TZ     TB  63832  HTTB
# 63844                                Tanga      TZ     TN  63844  HTTG
# 63845               Pemba / Karume Airport      TZ     PS  63845  HTPE
# 63862                               Dodoma      TZ     DO  63862  HTDO
# 63866                             Morogoro      TZ     MO  63866  HTMG
# 63870                   Zanzibar / Kisauni      TZ     ZU  63870  HTZA
# 63881                           Sumbawanga      TZ     RK  63881  HTSU
# 63887                               Iringa      TZ     IR  63887  HTIR
# 63894                Dar Es Salaam Airport      TZ     DS  63894  HTDA
# 63900                            Lyabusalu      TZ   <NA>  63900  HTSY
# 63919  Kilwa Masoko / Kilwamasoko / Kikone      TZ     LN  63919  HTKI
# 63932                                Mbeya      TZ     MB  63932  HTMB
# 63962                               Songea      TZ     RV  63962  HTSO
# 63969                           Nachingwea      TZ     LN  63969  HTNA
# 63971                               Mtwara      TZ     MT  63971  HTMT
# HTKB0                    Kibondo / Irabiro      TZ     KI   <NA>  HTKB
# HTMH0                                Makau      TZ     SI   <NA>  HTMH
# HTMP0                               Mpanda      TZ     RK   <NA>  HTMP
#
#        latitude  longitude  elevation              timezone hourly_start  \
# id
# 63729   -1.3333    31.8167     1137.0  Africa/Dar_es_Salaam   1957-01-01
# 63733   -1.5000    33.8000     1147.0  Africa/Dar_es_Salaam   1957-01-01
# 63756   -2.4667    32.9167     1139.0  Africa/Dar_es_Salaam   1950-01-08
# 63789   -3.3333    36.6167     1387.0  Africa/Dar_es_Salaam   1960-01-11
# 63790   -3.3500    37.3333      854.0  Africa/Dar_es_Salaam   1949-09-09
# 63791   -3.4167    37.0667      891.0  Africa/Dar_es_Salaam   1970-01-01
# 63801   -4.8833    29.6333      882.0  Africa/Dar_es_Salaam   1957-01-01
# 63816   -4.0833    37.7167      872.0  Africa/Dar_es_Salaam   1957-01-01
# 63818   -4.8833    38.2833      511.0  Africa/Dar_es_Salaam   1958-02-06
# 63832   -5.0833    32.8333     1181.0  Africa/Dar_es_Salaam   1949-01-21
# 63844   -5.0833    39.0667       39.0  Africa/Dar_es_Salaam   1957-01-01
# 63845   -5.2500    39.8167       25.0  Africa/Dar_es_Salaam   1957-01-01
# 63862   -6.1667    35.7667     1119.0  Africa/Dar_es_Salaam   1950-02-07
# 63866   -6.8333    37.6500      526.0  Africa/Dar_es_Salaam   1957-01-01
# 63870   -6.2167    39.2167       15.0  Africa/Dar_es_Salaam   1957-01-01
# 63881   -7.9667    31.6333     1923.0  Africa/Dar_es_Salaam   1989-09-02
# 63887   -7.6667    35.7500     1426.0  Africa/Dar_es_Salaam   1957-01-01
# 63894   -6.8667    39.2000       55.0  Africa/Dar_es_Salaam   1950-02-01
# 63900   -3.5000    33.0000     1168.0  Africa/Dar_es_Salaam   1988-03-24
# 63919   -8.9333    39.5167       18.0  Africa/Dar_es_Salaam   2005-07-01
# 63932   -8.9333    33.4667     1704.0  Africa/Dar_es_Salaam   1949-11-01
# 63962  -10.6833    35.5833     1067.0  Africa/Dar_es_Salaam   1949-01-21
# 63969  -10.3500    38.7500      463.0  Africa/Dar_es_Salaam   1957-01-01
# 63971  -10.2667    40.1833      113.0  Africa/Dar_es_Salaam   1957-01-01
# HTKB0   -3.5260    30.6504     1299.0  Africa/Dar_es_Salaam   2020-02-06
# HTMH0   -3.3711    34.8294     1623.0  Africa/Dar_es_Salaam   2011-07-08
# HTMP0   -6.3500    31.0830     1073.0  Africa/Dar_es_Salaam   2020-02-06
#
#       hourly_end daily_start  daily_end monthly_start monthly_end
# id
# 63729 2022-03-30  1950-01-01 2021-12-26    1950-01-01  1989-01-01
# 63733 2022-03-30  1950-01-01 2021-12-01    1950-01-01  1989-01-01
# 63756 2022-03-30  1950-01-01 2022-03-28    1950-01-01  2021-01-01
# 63789 2022-03-30  1959-02-01 2021-12-01    1959-01-01  1989-01-01
# 63790 2022-02-22  1950-01-01 1989-12-31    1950-01-01  1989-01-01
# 63791 2022-03-30  1971-10-01 2022-03-22    1971-01-01  1990-01-01
# 63801 2022-03-30  2006-12-13 2021-12-01           NaT         NaT
# 63816 2022-02-22  1950-01-01 1990-02-28    1950-01-01  1990-01-01
# 63818 2020-11-20         NaT        NaT           NaT         NaT
# 63832 2022-03-30  1951-08-01 2022-03-28    1949-01-01  2021-01-01
# 63844 2022-02-28         NaT        NaT           NaT         NaT
# 63845 2022-02-28         NaT        NaT           NaT         NaT
# 63862 2022-03-30  1957-01-01 2022-03-28    1957-01-01  2022-01-01
# 63866 2022-03-30  2006-03-12 2021-12-26           NaT         NaT
# 63870 2022-03-30  1957-01-01 2022-03-28    1957-01-01  2022-01-01
# 63881 2022-03-30  2008-06-23 2021-12-26           NaT         NaT
# 63887 2022-03-30  1960-01-01 2021-12-01    1960-01-01  1990-01-01
# 63894 2022-03-30  1957-01-01 2022-03-28    1949-01-01  2021-01-01
# 63900 2022-02-02         NaT        NaT           NaT         NaT
# 63919 2022-02-22         NaT        NaT           NaT         NaT
# 63932 2022-03-12  2005-10-06 2013-04-05           NaT         NaT
# 63962 2022-03-30  1957-01-01 2022-03-28    1949-01-01  2022-01-01
# 63969 2003-06-09         NaT        NaT           NaT         NaT
# 63971 2022-03-30  1957-01-01 2022-03-26    1957-01-01  2021-01-01
# HTKB0 2021-12-21         NaT        NaT           NaT         NaT
# HTMH0 2022-02-28         NaT        NaT           NaT         NaT
# HTMP0 2022-03-30         NaT        NaT           NaT         NaT

# %%
stations_df.plot()
# Out:
# <AxesSubplot:xlabel='id'>
